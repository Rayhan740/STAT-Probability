# %%
# Normal Distribution when (mean = 0 and SD = 1) -> Standard distribution 
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10,10,100) # taking input from -10 between 10 

Phi = (1/np.sqrt(2*np.pi)) * np.exp(-(x*x)/2) # Just taking the function when mean = 0 and SD = 1

# Plotting
plt.title('When mean = 0 and SD = 1') 
plt.xlabel('Input')
plt.ylabel('Output')
plt.plot(x,Phi)
plt.show()

# %%
# Importing required libraries
 
import numpy as np
import matplotlib.pyplot as plt
 
# Creating a series of data of in range of 1-50.
x = np.linspace(-10,10,100)

# Creating a function
def normal_Dist(x, μ, σ):
    prob = (1/σ*np.sqrt(2*np.pi)) * np.exp(-(1/2)*(x/σ)**2)
    return prob

#Giving value to the function

pdf1 = normal_Dist(x,0,0.5)
pdf2 = normal_Dist(x,0,1)
pdf3 = normal_Dist(x,0,1.5)
pdf4 = normal_Dist(x,0,2)

#plotting

plt.title('When  μ = 1 and σ varies then Normal Distribution')
plt.plot(x,pdf1,color="red")
plt.plot(x,pdf2,color="blue")
plt.plot(x,pdf3,color="green")
plt.plot(x,pdf4,color="yellow")

# %%
# Importing required libraries
 
import numpy as np
import matplotlib.pyplot as plt
 
# Creating a series of data of in range of 1-50.
x = np.linspace(-10,10,100)

# Creating a function
def normal_Dist(x, μ, σ):
    prob = (1/σ*np.sqrt(2*np.pi)) * np.exp(-(1/2)*((x-μ)/σ)**2)
    return prob


#Giving value to the function    

pdf1 = normal_Dist(x,0,1)
pdf2 = normal_Dist(x,0.5,1)
pdf3 = normal_Dist(x,1,1)
pdf4 = normal_Dist(x,1.5,1)

#Plott

plt.title('When  σ = 1 and μ varies then Normal Distribution')
plt.plot(x,pdf1,color="red")
plt.plot(x,pdf2,color="blue")
plt.plot(x,pdf3,color="green")
plt.plot(x,pdf4,color="yellow")
